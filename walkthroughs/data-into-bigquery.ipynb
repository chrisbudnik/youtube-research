# %%
import sys
sys.path.append(r"/Users/chrisbudnik/Desktop/Projects/youtube-research")

import importlib
import databases.bigquery_schemas as bs
importlib.reload(bs)
import databases.bigquery_connector as bc 
importlib.reload(bc)

from pprint import pprint

# %% [markdown]
# ## **Creating Project Tables**

# %%
conn = bc.BigQueryConnector(dataset_id="youtube")
conn.automated_create_tables()
# Out:
# Creating main project tables...: 4it [00:02,  1.43it/s]
# Succesfully created youtube-research tables: ['video_base', 'video_stats', 'video_text', 'channels']
