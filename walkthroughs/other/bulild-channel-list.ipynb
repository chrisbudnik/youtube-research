# %% [markdown]
# ## **Notebook Setup** </br>
# When working with jupyter files, accesing modules outside of notebook directory can be tricky. </br>
# That is why I use `sys.path.append` to help jupter find required modules for handling youtube content. </br>
# If you want this to work on your machine, simply modify the path to project files, in my case the folder's </br>
# name is `youtube-research`.

# %%
import sys
sys.path.append(r"/Users/chrisbudnik/Desktop/Projects/youtube-research")

from models import search
from models.content import channel
from models.search import YouTubeSearch
from models.content import Video, Channel

import importlib
importlib.reload(search)
importlib.reload(channel)

from pprint import pprint

# %% [markdown]
# ## **Walkthrough Outline**
# - **exact search** - using `YoutubeSearch` class to simplify the process of finding channel ids based on provided names.
# - **channel discovery** - example implementation of `collect_best_ranking_channels()` method to find channels </br>
# based on search terms and best ranking videos

# %% [markdown]
# ## **Exact Search**
# *description in progress*

# %% [markdown]
# ### **Unpack `.txt` file**
# *description in progress*

# %%
with open('/Users/chrisbudnik/Desktop/Projects/youtube-research/datasets/exact-search-channels.txt', 'r') as file:
    exact_search_terms = [line.strip() for line in file]

# Check number of search terms
print(f"Number of Search terms: {len(exact_search_terms)}", "\n")

pprint(exact_search_terms)
# Out:
# Number of Search terms: 15
#
# ['graham stephen',
#  'andrei jikh',
#  'joshua mayo',
#  'the graham stephan show',
#  'liam ottley',
#  'ruri ohama',
#  'brian jung',
#  'mark tilbury',
#  'vincent chan',
#  'greg gottfried',
#  'mike vestil',
#  'ali abdaal',
#  'noah kagan',
#  'thomas frank',
#  "matt d'avella"]

# %% [markdown]
# ### **Using `YoutubeSearch`**
# *description in progress*
# - instance of `YoutubeSearch`
# - results
# - one missing

# %%
exact_search = search.YouTubeSearch(keywords=exact_search_terms)
results = exact_search.collect_exact_terms()

# %%
pprint(results)
# Out:
# [Channel(channel_id=UCGy7SkBjcIAgTiwkXEtPnYg, channel_name=Andrei Jikh),
#  Channel(channel_id=UCJZ7zr9a6AT6STkyOFztgiQ, channel_name=Joshua Mayo),
#  Channel(channel_id=UCa-ckhlKL98F8YXKQ-BALiw, channel_name=The Graham Stephan Show),
#  Channel(channel_id=UCui4jxDaMb53Gdh-AZUTPAg, channel_name=Liam Ottley),
#  Channel(channel_id=UCKtiMrNZq0gGbPTnsMu7Bsw, channel_name=Ruri Ohama),
#  Channel(channel_id=UCQglaVhGOBI0BR5S6IJnQPg, channel_name=Brian Jung),
#  Channel(channel_id=UCxgAuX3XZROujMmGphN_scA, channel_name=Mark Tilbury),
#  Channel(channel_id=UCPa0bvFsR1mbBpk5mIPFGLA, channel_name=Vincent Chan),
#  Channel(channel_id=UCZAoatH4HngcEuCtOWuSX2A, channel_name=Greg Gottfried),
#  Channel(channel_id=UCYONTR6PoZVJ4EcbOz3qdtw, channel_name=Mike Vestil),
#  Channel(channel_id=UCoOae5nYA7VqaXzerajD0lg, channel_name=Ali Abdaal),
#  Channel(channel_id=UCF2v8v8te3_u4xhIQ8tGy1g, channel_name=Noah Kagan),
#  Channel(channel_id=UCG-KntY7aVnIGXYEBQvmBAQ, channel_name=Thomas Frank),
#  Channel(channel_id=UCJ24N4O0bP7LGLBDvye7oCA, channel_name=Matt D'Avella)]

# %% [markdown]
# ### **Collect Channel Data**
# *description in progress*
# - use `info()` method
# - save into csv file

# %%
import csv

with open('/Users/chrisbudnik/Desktop/Projects/youtube-research/datasets/channels-list-own.csv', 'w') as file:
    writer = csv.writer(file)
    header = ["channel_id", "channel_name", "uploads_playlist_id", "subscriber_count"]
    writer.writerow(header)

    for channel in results:
        # use `info()` method to access all channel properties`
        channel_info = list(channel.info())
        writer.writerow(channel_info)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[60], line 10
#       6 writer.writerow(header)
#       8 for channel in results:
#       9     # use `info()` method to access all channel properties`
# ---> 10     channel_info = list(channel.info())
#      11     writer.writerow(channel_info)
#
# File ~/Desktop/Projects/youtube-research/models/content/channel.py:70, in Channel.info(self)
#      66 def info(self) -> tuple:
#      67     """
#      68     Returns in a tuple: channel ID, channel name, channel uploads playlist ID and subscriber count.
#      69     """
# ---> 70     return (self.channel_id, self.channel_name, self.uploads_playlist_id, self.subscriber_count)
#
# File ~/Desktop/Projects/youtube-research/models/content/channel.py:51, in Channel.uploads_playlist_id(self)
#      46 """
#      47 The ID of the playlist containing all the uploads of the channel,
#      48 lazily loaded upon first access.
#      49 """
#      50 if self._uploads_playlist_id is None:
# ---> 51     self._uploads_playlist_id = self.get_playlist_id(type="uploads")
#      52 return self._uploads_playlist_id
#
# File ~/Desktop/Projects/youtube-research/models/content/channel.py:96, in Channel.get_playlist_id(self, type)
#      91 def get_playlist_id(self, type: str = "uploads") -> str:
#      92     """
#      93     Retrieves the ID of a specific type of playlist associated with the channel,
#      94     e.g., "uploads" for the channel's uploaded videos.
#      95     """
# ---> 96     channel_response = self.get_channel_response(self.channel_id, 'contentDetails')
#      97     playlist_id = channel_response['items'][0]['contentDetails']['relatedPlaylists'][type]
#      98     return playlist_id
#
# File ~/Desktop/Projects/youtube-research/models/content/content.py:29, in YouTubeAPI.get_channel_response(self, channel_id, part)
#      25 def get_channel_response(self, channel_id: str, part: str):
#      26     return self.youtube.channels().list(
#      27         part=part,
#      28         id=channel_id
# ---> 29     ).execute()
#
# File ~/miniconda3/envs/youtube/lib/python3.10/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/envs/youtube/lib/python3.10/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&id=UCJZ7zr9a6AT6STkyOFztgiQ&key=AIzaSyAtbvxuCI6CKkcCHs6XYf0VinxPCSlrtBk&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %% [markdown]
# ## **Channel Discovery**
# *description in progress*

# %% [markdown]
# ### **Defining Seach Terms**
# In this walktrhough I will focus on personal finance / side hustle niches.

# %%
# Open the file and process terms
with open('/Users/chrisbudnik/Desktop/Projects/youtube-research/datasets/search-terms.txt', 'r') as file:
    search_terms = [line.strip().strip('"')  for line in file]

# Check number of search terms
print(f"Number of Search terms: {len(search_terms)}", "\n")

# Show top 5 search terms
pprint(search_terms[:5])
# Out:
# Number of Search terms: 80
#
# ['Budgeting for beginners',
#  'Personal finance tips',
#  'Retirement savings strategies',
#  'Investing for millennials',
#  'Debt reduction plans']

# %% [markdown]
# ### **Finding channels with `YoutubeSearch`**
# - to ensure we dont't cross the limit of api calls, I created a `sample` that consists of top search terms saved in `search-terms.txt`
# - with `collect_best_ranking_channels()` method I first have collected top ranking videos and then extracted channel names and ids

# %%
sample = search_terms[:5]
search = YouTubeSearch(keywords=sample)

# %%
channels = search.collect_best_ranking_channels(max_results = 50, order_by="viewCount", only_unique=True)

# %%
print(f"With youtube search we found {len(channels)} unique channels", "\n")

print("Printing top 10 results")
pprint(channels[:5])
# Out:
# With youtube search we found 184 unique channels
#
# Printing top 10 results
# [Channel(channel_id=UCLONtfJllb_6T0yv4KNOYdA, channel_name=The Financial Beat),
#  Channel(channel_id=UCpr0Iy4B-oSQkiqrk_pmebw, channel_name=Amy's Lifestyle & Budget),
#  Channel(channel_id=UCwsErI9yX0Nh-tSJdHNgYEw, channel_name=Senior Affair),
#  Channel(channel_id=UCPvDRksk6y4lRgY6CJ6cMdg, channel_name=swamikrupa137.1Mviews),
#  Channel(channel_id=UCsBsbMIriYyzKNkqSoHuL3A, channel_name=FinanciallyFurious)]

# %% [markdown]
# ### **Saving Channel Names**

# %%
with open('channel_names.txt', 'w') as file:
    for channel in channels:
        file.write(f'{channel.channel_name}\n')
